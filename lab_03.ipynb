# %% [markdown]
# # Práctica 3. Operaciones sobre imágenes en escala de gris
#
# <div class="alert alert-block alert-success">
# <b>Resumen:</b> Esta práctica presenta un código que realiza operaciones básicas sobre una imagen en escala de grises utilizando Python y OpenCV. Incluye la lectura y visualización de una imagen de prueba, la creación de una copia, la manipulación de píxeles para dibujar líneas horizontales y verticales, la modificación de subregiones específicas de la imagen, y su segmentación en función de umbrales unilaterales y bilaterales.
# </div>
#
# ***

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1. Imágenes en escala de grises
#
# Lectura de la imagen

# %%
im_gray = cv2.imread('.\images\cameraman.tif', cv2.IMREAD_UNCHANGED)

# %% [markdown]
# Atributos de la imagen

# %%
print(f'Forma de la imagen: {im_gray.shape}')
print(f'Tipo de datos: {im_gray.dtype}')

# %% [markdown]
# Visualización de la imagen

# %%
plt.imshow(im_gray, cmap='gray')
plt.title('Imagen Original')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 2. Operaciones
# ### 2.1 Copia de la imagen

# %%
im_gray_2 = im_gray.copy()

# %% [markdown]
# ### 2.2 Operador :
# #### 2.2.1 Dibujo de una línea horizontal
#
# Dado que la imagen es tipo UINT8 los valores de los píxeles varían entre [0, 255]

# %%
im_gray_2[50, :] = 0

# %%
plt.imshow(im_gray_2, cmap='gray')
plt.title('Línea Horizontal')
#plt.axis('off')
plt.show()

# %% [markdown]
# #### 2.2.2 Dibujo de una línea vertical

# %%
im_gray_2[:, 100] = 0

# %%
plt.imshow(im_gray_2, cmap='gray')
plt.title('Línea Vertical')
plt.axis('off')
plt.show()

# %% [markdown]
# ### 2.3 Operador a:b

# %%
im_gray_2[80:120, 10:150] = 200

# %%
plt.imshow(im_gray_2, cmap='gray')
plt.title('Operador a:b')
plt.axis('on')
plt.show()

# %% [markdown]
# ### 2.4 Segmentación
# #### 2.4.1 Uni-lateral

# %%
im_bw_s1 = im_gray > 20

# %%
plt.imshow(im_bw_s1, cmap='gray')
plt.title('Segmentación Uni-lateral (im_gray > 20)')
plt.axis('off')
plt.show()

# propiedades de im_bw_s1
print(f'\nForma de la imagen: {im_bw_s1.shape}')
print(f'Tipo de datos: {im_bw_s1.dtype}')

# %%
im_bw_s2 = np.logical_not(im_bw_s1)

# %%
plt.imshow(im_bw_s2, cmap='gray')
plt.title('Segmentación Uni-lateral (invertida)')
plt.axis('off')
plt.show()

# %% [markdown]
# #### 2.4.2 Bi-lateral

# %%
im_bw_s3 = (im_gray > 10) & (im_gray < 50)

# %%
plt.imshow(im_bw_s3, cmap='gray')
plt.title('Segmentación Bi-lateral (10 < im_gray < 50)')
plt.axis('off')
plt.show()

# %% [markdown]
# <div style="margin: 20px 0; text-align:center;">
#   <div style="width:72%; margin:0 auto; position:relative;">
#     <hr style="border:none; height:2px; background: linear-gradient(90deg, transparent, #444, transparent);" />
#     <div style="position:absolute; left:50%; top:50%; transform:translate(-50%,-50%);
#       width:12px; height:12px; border-radius:50%;
#       background: radial-gradient(circle, #fff, #f59e0b, transparent 70%);
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="margin: 14px 0; text-align:left;">
#   <div style="display:inline-block; padding: 5px 10px; border-radius: 999px;
#     background: #e5e7eb; color:#111827; font-weight:600; letter-spacing:.2px;
#     border: 1px solid #d1d5db;">
#     Actividades
#   </div>
# </div>

# %% [markdown]
# 1. Dibuje una línea horizontal y una línea vertical sobre una imagen utilizando slicing con el operador : (por ejemplo, modificando directamente filas y columnas del arreglo de la imagen), sin usar funciones de dibujo como cv2.line()

# %%
# <-- aquí su código -->

# %% [markdown]
# 2. Construya una máscara binaria (0 y 255) que permita observar únicamente el rostro de la persona en la imagen. La máscara debe cubrir toda el área del rostro (incluyendo ojos, nariz y boca) y dejar el resto de la imagen en negro. Finalmente, aplique la máscara sobre la imagen original y muestre como resultado una imagen donde solo el rostro sea visible.

# %%
# <-- aquí su código -->
